# %% [markdown]
# # Not live value part of the code

# %%
import matplotlib.pyplot as plt
import pandas as pd
import random

# %%
# Read in the data
df_touched = pd.read_csv('data_touched.csv')
df_untouched = pd.read_csv('data_untouched.csv')

# %%
# pandas display the touched data summary
df_touched.describe()
# Out:
#          100 kHz     101 kHz     102 kHz     103 kHz     104 kHz     105 kHz  \
# count  300.00000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean     0.08940    0.100500    0.071300    0.099167    0.093167    0.085600
# std      0.07094    0.062944    0.066995    0.063827    0.061266    0.069911
# min      0.00000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.05000    0.050000    0.000000    0.060000    0.050000    0.040000
# 50%      0.07000    0.090000    0.050000    0.080000    0.080000    0.070000
# 75%      0.13000    0.122500    0.110000    0.130000    0.120000    0.122500
# max      0.35000    0.340000    0.360000    0.390000    0.320000    0.300000
#
#           106 kHz     107 kHz     108 kHz     109 kHz  ...     290 kHz  \
# count  300.000000  300.000000  300.000000  300.000000  ...  300.000000
# mean     0.091400    0.051600    0.060300    0.085700  ...    0.072300
# ...

# %%
# pandas display the untouched data summary
df_untouched.describe()
# Out:
#           100 kHz     101 kHz     102 kHz     103 kHz     104 kHz     105 kHz  \
# count  300.000000  300.000000  300.000000  300.000000  300.000000  300.000000
# mean     0.869433    0.596767    0.432100    0.619833    0.508900    0.610033
# std      0.135765    0.098852    0.070729    0.098689    0.094779    0.077535
# min      0.590000    0.320000    0.270000    0.300000    0.250000    0.400000
# 25%      0.767500    0.570000    0.380000    0.590000    0.440000    0.580000
# 50%      0.860000    0.610000    0.420000    0.630000    0.480000    0.610000
# 75%      0.980000    0.650000    0.470000    0.662500    0.580000    0.650000
# max      1.230000    1.010000    0.690000    0.850000    0.770000    0.850000
#
#           106 kHz     107 kHz     108 kHz     109 kHz  ...     290 kHz  \
# count  300.000000  300.000000  300.000000  300.000000  ...  300.000000
# mean     0.570400    0.421233    0.425200    0.473200  ...    0.793200
# ...

# %% [markdown]
# ## Vizualization of the data using line plot

# %% [markdown]
# The following vizualization is done on the untouched dataset

# %%
df_untouched[['100 kHz', '150 kHz', '200 kHz','250 kHz', '299 kHz']].plot(legend=True, kind = 'line', figsize=(25, 5), xlabel='Value id', ylabel='Voltage')
# print another plot with different columns 
df_untouched[['100 kHz', '101 kHz','102 kHz', '103 kHz', '103 kHz']].plot(legend=True, kind = 'line', figsize=(25, 5), xlabel='Value id', ylabel='Voltage')
plt.show()

# %% [markdown]
# The following vizualization is done on the touched dataset

# %%
df_touched[['100 kHz', '150 kHz', '200 kHz','250 kHz', '299 kHz']].plot(legend=True, kind = 'line', figsize=(25, 5), xlabel='Value id', ylabel='Voltage')
# print another plot with different columns 
df_touched[['100 kHz', '101 kHz','102 kHz', '103 kHz', '103 kHz']].plot(legend=True, kind = 'line', figsize=(25, 5), xlabel='Value id', ylabel='Voltage')
plt.show()

# %% [markdown]
# The following visualization is done on the untouched dataset
# will take 4 randomly chosen value id and display the voltage value

# %%
df_untouched.iloc[1].plot(legend=True, kind = 'line', figsize=(25, 5), xlabel='frequency', ylabel='Voltage response')
df_untouched.iloc[100].plot(legend=True, kind = 'line', figsize=(25, 5), xlabel='frequency', ylabel='Voltage response')
df_untouched.iloc[50].plot(legend=True, kind = 'line', figsize=(25, 5), xlabel='frequency', ylabel='Voltage response')
df_untouched.iloc[299].plot(legend=True, kind = 'line', figsize=(25, 5), xlabel='frequency', ylabel='Voltage response')
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='Voltage response'>

# %% [markdown]
# The following visualization is done on the touched dataset
# will take the same 4 randomly chosen value id and display the voltage value

# %%
df_touched.iloc[1].plot(legend=True, kind = 'line', figsize=(25, 5), xlabel='frequency', ylabel='Voltage response')
df_touched.iloc[100].plot(legend=True, kind = 'line', figsize=(25, 5), xlabel='frequency', ylabel='Voltage response')
df_touched.iloc[50].plot(legend=True, kind = 'line', figsize=(25, 5), xlabel='frequency', ylabel='Voltage response')
df_touched.iloc[299].plot(legend=True, kind = 'line', figsize=(25, 5), xlabel='frequency', ylabel='Voltage response')
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='Voltage response'>
